# %%
import numpy as np
import pandas as pd

# %%
# !wget http://airo.maynoothuniversity.ie/files/dDATASTORE/crime/garda%20stations/garda_stations.csv
# Out:
# --2019-01-19 19:29:31--  http://airo.maynoothuniversity.ie/files/dDATASTORE/crime/garda%20stations/garda_stations.csv
# Resolving airo.maynoothuniversity.ie (airo.maynoothuniversity.ie)... 149.157.67.11
# Connecting to airo.maynoothuniversity.ie (airo.maynoothuniversity.ie)|149.157.67.11|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 265570 (259K) [text/csv]
# Saving to: ‘garda_stations.csv’
#
# garda_stations.csv  100%[===================>] 259.35K  --.-KB/s    in 0.1s
#
# 2019-01-19 19:29:31 (2.54 MB/s) - ‘garda_stations.csv’ saved [265570/265570]

# %%
df = pd.read_csv("garda_stations.csv", engine="python")

# %%
df.sort_values('x')
# Out:
#         id                 Station                       Divisions         x  \
# 40   20384  Baile an Fheirt�araigh                  Kerry Division   35414.0
# 461  20391               Portmagee                  Kerry Division   37438.0
# 222  20381                  Dingle                  Kerry Division   44605.0
# 134  20387             Caherciveen                  Kerry Division   47419.0
# 10   20393              An Coirean                  Kerry Division   50174.0
# 17   20383               Annascaul                  Kerry Division   59567.0
# 167  20382           Castlegregory                  Kerry Division   62067.0
# 313  20591                    Keel                   Mayo Division   63428.0
# 182  20483                 Clifden                 Galway Division   66684.0
# 284  20390               Glenbeigh                  Kerry Division   67187.0
# 172  20351          Castletownbere              Cork West Division   67530.0
# ...
